# %% [markdown]
# # Uber Data Analysis To Predict Cab Fare

# %% [markdown]
# ## Importing libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set_style('whitegrid')

# %% [markdown]
# ## Importing dataset

# %%
cab_data = pd.read_csv('data/Uber Dataset/cab_rides.csv')
weather_data = df = pd.read_csv('data/Uber Dataset/weather.csv')

# %%
cab_data.head()
# Out:
#    distance cab_type     time_stamp    destination            source  price  \
# 0      0.44     Lyft  1544952607890  North Station  Haymarket Square    5.0
# 1      0.44     Lyft  1543284023677  North Station  Haymarket Square   11.0
# 2      0.44     Lyft  1543366822198  North Station  Haymarket Square    7.0
# 3      0.44     Lyft  1543553582749  North Station  Haymarket Square   26.0
# 4      0.44     Lyft  1543463360223  North Station  Haymarket Square    9.0
#
#    surge_multiplier                                    id    product_id  \
# 0               1.0  424553bb-7174-41ea-aeb4-fe06d4f4b9d7     lyft_line
# 1               1.0  4bd23055-6827-41c6-b23b-3c491f24e74d  lyft_premier
# 2               1.0  981a3613-77af-4620-a42a-0c0866077d1e          lyft
# 3               1.0  c2d88af2-d278-4bfd-a8d0-29ca77cc5512   lyft_luxsuv
# 4               1.0  e0126e1f-8ca9-4f2e-82b3-50505a09db9a     lyft_plus
#
#            name
# 0        Shared
# 1           Lux
# 2          Lyft
# ...

# %%
weather_data.head()
# Out:
#     temp            location  clouds  pressure    rain  time_stamp  humidity  \
# 0  42.42            Back Bay     1.0   1012.14  0.1228  1545003901      0.77
# 1  42.43         Beacon Hill     1.0   1012.15  0.1846  1545003901      0.76
# 2  42.50   Boston University     1.0   1012.15  0.1089  1545003901      0.76
# 3  42.11              Fenway     1.0   1012.13  0.0969  1545003901      0.77
# 4  43.13  Financial District     1.0   1012.14  0.1786  1545003901      0.75
#
#     wind
# 0  11.25
# 1  11.32
# 2  11.07
# 3  11.09
# 4  11.49

# %%
cab_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 693071 entries, 0 to 693070
# Data columns (total 10 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   distance          693071 non-null  float64
#  1   cab_type          693071 non-null  object
#  2   time_stamp        693071 non-null  int64
#  3   destination       693071 non-null  object
#  4   source            693071 non-null  object
#  5   price             637976 non-null  float64
#  6   surge_multiplier  693071 non-null  float64
#  7   id                693071 non-null  object
#  8   product_id        693071 non-null  object
#  9   name              693071 non-null  object
# dtypes: float64(3), int64(1), object(6)
# memory usage: 52.9+ MB

# %%
cab_data.isnull().sum()
# Out:
# distance                0
# cab_type                0
# time_stamp              0
# destination             0
# source                  0
# price               55095
# surge_multiplier        0
# id                      0
# product_id              0
# name                    0
# dtype: int64

# %%
cab_data.describe()
# Out:
#             distance    time_stamp          price  surge_multiplier
# count  693071.000000  6.930710e+05  637976.000000     693071.000000
# mean        2.189430  1.544046e+12      16.545125          1.013870
# std         1.138937  6.891925e+08       9.324359          0.091641
# min         0.020000  1.543204e+12       2.500000          1.000000
# 25%         1.280000  1.543444e+12       9.000000          1.000000
# 50%         2.160000  1.543737e+12      13.500000          1.000000
# 75%         2.920000  1.544828e+12      22.500000          1.000000
# max         7.860000  1.545161e+12      97.500000          3.000000

# %%
weather_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6276 entries, 0 to 6275
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   temp        6276 non-null   float64
#  1   location    6276 non-null   object
#  2   clouds      6276 non-null   float64
#  3   pressure    6276 non-null   float64
#  4   rain        894 non-null    float64
#  5   time_stamp  6276 non-null   int64
#  6   humidity    6276 non-null   float64
#  7   wind        6276 non-null   float64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 392.4+ KB

# %%
weather_data.isnull().sum()
# Out:
# temp             0
# location         0
# clouds           0
# pressure         0
# rain          5382
# time_stamp       0
# humidity         0
# wind             0
# dtype: int64

# %%
weather_data.describe()
# Out:
#               temp       clouds     pressure        rain    time_stamp  \
# count  6276.000000  6276.000000  6276.000000  894.000000  6.276000e+03
# mean     39.090475     0.677777  1008.445209    0.057652  1.543857e+09
# std       6.022055     0.314284    12.870775    0.100758  6.659340e+05
# min      19.620000     0.000000   988.250000    0.000200  1.543204e+09
# 25%      36.077500     0.440000   997.747500    0.004900  1.543387e+09
# 50%      40.130000     0.780000  1007.660000    0.014850  1.543514e+09
# 75%      42.832500     0.970000  1018.480000    0.060925  1.544691e+09
# max      55.410000     1.000000  1035.120000    0.780700  1.545159e+09
#
#           humidity         wind
# count  6276.000000  6276.000000
# mean      0.763985     6.802812
# std       0.127340     3.633466
# min       0.450000     0.290000
# 25%       0.670000     3.517500
# 50%       0.760000     6.570000
# 75%       0.890000     9.920000
# max       0.990000    18.180000

# %%
import datetime
cab_data['datetime'] = pd.to_datetime(cab_data['time_stamp'])
weather_data['datetime'] = pd.to_datetime(weather_data['time_stamp'])

# %%
cab_data.head()
# Out:
#    distance cab_type     time_stamp    destination            source  price  \
# 0      0.44     Lyft  1544952607890  North Station  Haymarket Square    5.0
# 1      0.44     Lyft  1543284023677  North Station  Haymarket Square   11.0
# 2      0.44     Lyft  1543366822198  North Station  Haymarket Square    7.0
# 3      0.44     Lyft  1543553582749  North Station  Haymarket Square   26.0
# 4      0.44     Lyft  1543463360223  North Station  Haymarket Square    9.0
#
#    surge_multiplier                                    id    product_id  \
# 0               1.0  424553bb-7174-41ea-aeb4-fe06d4f4b9d7     lyft_line
# 1               1.0  4bd23055-6827-41c6-b23b-3c491f24e74d  lyft_premier
# 2               1.0  981a3613-77af-4620-a42a-0c0866077d1e          lyft
# 3               1.0  c2d88af2-d278-4bfd-a8d0-29ca77cc5512   lyft_luxsuv
# 4               1.0  e0126e1f-8ca9-4f2e-82b3-50505a09db9a     lyft_plus
#
#            name                      datetime
# ...

# %%
merged_data = pd.concat([cab_data, weather_data])
merged_data.head()
# Out:
#    distance cab_type     time_stamp    destination            source  price  \
# 0      0.44     Lyft  1544952607890  North Station  Haymarket Square    5.0
# 1      0.44     Lyft  1543284023677  North Station  Haymarket Square   11.0
# 2      0.44     Lyft  1543366822198  North Station  Haymarket Square    7.0
# 3      0.44     Lyft  1543553582749  North Station  Haymarket Square   26.0
# 4      0.44     Lyft  1543463360223  North Station  Haymarket Square    9.0
#
#    surge_multiplier                                    id    product_id  \
# 0               1.0  424553bb-7174-41ea-aeb4-fe06d4f4b9d7     lyft_line
# 1               1.0  4bd23055-6827-41c6-b23b-3c491f24e74d  lyft_premier
# 2               1.0  981a3613-77af-4620-a42a-0c0866077d1e          lyft
# 3               1.0  c2d88af2-d278-4bfd-a8d0-29ca77cc5512   lyft_luxsuv
# 4               1.0  e0126e1f-8ca9-4f2e-82b3-50505a09db9a     lyft_plus
#
#            name                      datetime  temp location  clouds  \
# ...

# %%
merged_data['day'] = merged_data.datetime.dt.day
merged_data['hour'] = merged_data.datetime.dt.hour

# %%
merged_data.fillna(0, inplace=True)
merged_data.isnull().sum()
# Out:
# distance            0
# cab_type            0
# time_stamp          0
# destination         0
# source              0
# price               0
# surge_multiplier    0
# id                  0
# product_id          0
# name                0
# datetime            0
# temp                0
# location            0
# clouds              0
# pressure            0
# rain                0
# humidity            0
# wind                0
# day                 0
# hour                0
# dtype: int64

# %%
merged_data.groupby('cab_type').count()
# Out:
#           distance  time_stamp  destination  source   price  surge_multiplier  \
# cab_type
# 0             6276        6276         6276    6276    6276              6276
# Lyft        307408      307408       307408  307408  307408            307408
# Uber        385663      385663       385663  385663  385663            385663
#
#               id  product_id    name  datetime    temp  location  clouds  \
# cab_type
# 0           6276        6276    6276      6276    6276      6276    6276
# Lyft      307408      307408  307408    307408  307408    307408  307408
# Uber      385663      385663  385663    385663  385663    385663  385663
#
#           pressure    rain  humidity    wind     day    hour
# cab_type
# 0             6276    6276      6276    6276    6276    6276
# Lyft        307408  307408    307408  307408  307408  307408
# Uber        385663  385663    385663  385663  385663  385663

# %%
plt.figure(figsize=(15, 8))
merged_data.groupby('cab_type').count().plot.bar()
plt.show()

# %%
merged_data['price'].value_counts().plot(kind='bar', figsize=(100, 50), color="blue")
plt.show()

# %%
merged_data['hour'].value_counts().plot(kind='bar', figsize=(10, 5), color='blue')
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(15, 8))
# plt.scatter(merged_data['distance'][:50], merged_data['price'][:50], cmap='cividis')
sns.scatterplot(x = 'distance', y='price', data=merged_data)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.title('Price over distance', fontsize=10)
plt.xlabel('Distance')
plt.ylabel('Price')
plt.show()

# %%
plt.figure(figsize=(15, 8))

sns.barplot(x = 'distance', y='price', data=merged_data)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.title('Price over distance', fontsize=10)
plt.xlabel('Distance')
plt.ylabel('Price')
plt.show()

# %%
plt.figure(figsize=(15, 8))
sns.scatterplot(x = 'rain', y='price', data=merged_data)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.title('Price over rain weather', fontsize=10)
plt.xlabel('Rain')
plt.ylabel('Price')
plt.show()

# %%
plt.figure(figsize=(15, 8))
sns.scatterplot(x = 'hour', y='price', data=merged_data)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.title('Price over hour', fontsize=10)
plt.xlabel('Distance')
plt.ylabel('Price')
plt.show()

# %%
## Splitting the data into train and test set considering only some of the features
X = merged_data[['distance', 'temp', 'pressure', 'humidity', 'wind', 'rain', 'day', 'hour', 'surge_multiplier', 'clouds']]
y = merged_data['price']

from sklearn.preprocessing import StandardScaler
ss = StandardScaler()
X = ss.fit_transform(X)

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_preds = model.predict(X_test)
y_preds
# Out:
# array([32.54722234, 14.75563929, 16.81698669, ..., 11.82903496,
#        11.8544837 , 13.22871529])

# %%
print('Accuracy: ', model.score(X_test, y_test))
# Out:
# Accuracy:  0.1563839239667466
